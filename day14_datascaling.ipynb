# %% [markdown]
# ### KNN

# %%
-distance based algorithm 
- value of k (number of neighbours)
 -if k =5 ,it selects top 5 minimum distance  value ra jasko dherei chha tehi predict garchhaa

# %% [markdown]
# ### Data scaling
# ### Label Encoding

# %%
KNN vitraa data scaling parchhaa

# %% [markdown]
# ### Label Encoding

# %%
LABEL ENCODING
- sklearn bata pani garnna sakenchha label encoding
-

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder # yeslee encoding gardenchhaa
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
yesmma species ma label encoding lagauna jaruri
chha kinabhaney aru mata already numeric mai chha data

# %%
#use gareko fxn ko naam : .fit_transfromer()
encoder = LabelEncoder()
df['Label']= encoder.fit_transform(df.species)

aagdi ko df['Label'] le gardaa tala table ma label bhanney naya column banaidenchha

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  Label
# 0             5.1          3.5           1.4          0.2     setosa      0
# 1             4.9          3.0           1.4          0.2     setosa      0
# 2             4.7          3.2           1.3          0.2     setosa      0
# 3             4.6          3.1           1.5          0.2     setosa      0
# 4             5.0          3.6           1.4          0.2     setosa      0
# ..            ...          ...           ...          ...        ...    ...
# 145           6.7          3.0           5.2          2.3  virginica      2
# 146           6.3          2.5           5.0          1.9  virginica      2
# 147           6.5          3.0           5.2          2.0  virginica      2
# 148           6.2          3.4           5.4          2.3  virginica      2
# 149           5.9          3.0           5.1          1.8  virginica      2
#
# [150 rows x 6 columns]

# %%
encoder.classes_ #encoder ko classes denchha
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.Label.unique()
# Out:
# array([0, 1, 2])

# %%
yo bhaneko setosa => 0
          Versicolor=>1
         virginica => 2
assign bhayo

# %%
Label encoder ra map function ma k difference?
-> Alphabetical order aanusar assign gardenchha 
ie: 'setosa', 'versicolor', 'virginica' , yo 3 otaa lai alphabetically order
garepachhi matraa balla label assign gardenchha.

# %% [markdown]
# ### Data Scaling

# %%
Data Scaling

-> scaling bhaneko k ho vandaa , hami snagaa vako column of variable ko
data ko range yeutei chhaina chhutaa chhutei chha bhaney we should use data scaling

-> suppose hami sangaa 2 ottaa columns cha ie; 
     1) AGE (range : 21-80)
     2) Insulin (Insulin : 0-450)
yo 2 ottaa bataa hami lai diabetes predict garnu chha,

-> yeni haru range nai farak farak chha
-> suppose we have 1 data: Age = 40, insulin = 300
   suppose we have another  data: Age = 42, insulin = 100 chha
  now KNN ley  ta diatance nekalertaa garchhaa,
     distance = root over (40-42)^2 +(300-100)^2
              =root over 2^2 + (-200)^2
yeutaa ma 2 ko square 4
arko ma 200 ko square gardaa 2000000

-> yesto value aauda high value aako ley chhai sano value lai dominant garchha
-> diatance based ko calculation chaa bahney yeni ahru lai range ma lyaunu parchha
ani ballaa distance formlulaa lagaune ; ie: same rangee ma lyaunee 
this process is called data scaling .

# %% [markdown]
# ### Data scaling
# -> data set haru lai commom range ko banaune.
#
# Data scaling techniques
#
# 1) Min _ Max Scaling (Normalization)
#    -> values lai convert gareraa 0 to 1 ko bich ma aauchhaa
#    -> formula : (x-min)/(max-min)
#
# 3) Standardization (Z - score Normalization)
#    -> mean = 0 and std = 1
#
#    -> formula : x -meu / sigma
#
#    ie: z = score - mean / SD(standard deviation)
#
#    -> normally bahnney vane -1 to 1 ko range ma aauchha.

# %%
#Data scaling

1.MinMax Scaling
   xscaled =(x - xmin) / (xmax -xmin) : range(0-1)
-> yeslai aru range mani convert garna parnaa sakchha ie jasto hamalai 2-10 ko range ma chaiyo bahney
    fromula :xnew_min+((x-xmin)/(xmax-xmin)) * (xnew_max-xnew_min)
        here xnew min = 2
             xnew max =10

2. Z - score normalization
  scaled = x -min/std

# %%
data = pd.read_csv('Diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
here we are doing : glucose ra Age bata diabetes predict gardei chham using KNN

# %%
here  glucose herne bhane range 0 to 199 
      age  ko range: 21 to 81

# %%
so yeaha scaling garnu  parchhaa yeutei range ma lyaunaa ko lagi

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#if standard scaler lagaune bhako vaye
kunei yeutaa column lai leraa tyo whole column ma scaling garnaa lako 
blood pressure bhanney column leko

scaler = StandardScaler()
data['BloodPressure']=scaler.fit_transform(data[['BloodPressure']])

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148       0.149641             35        0  33.6
# 1            1       85      -0.160546             29        0  26.6
# 2            8      183      -0.263941              0        0  23.3
# 3            1       89      -0.160546             23       94  28.1
# 4            0      137      -1.504687             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
yehhaaa standard scaler ma 
mean = 0
standard deviation = 1
+ve , -ve both hunchhaa values

# %%
data.describe(
    
)
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000   7.680000e+02     768.000000  768.000000
# mean      3.845052  120.894531   1.503427e-17      20.536458   79.799479
# std       3.369578   31.972618   1.000652e+00      15.952218  115.244002
# min       0.000000    0.000000  -3.572597e+00       0.000000    0.000000
# 25%       1.000000   99.000000  -3.673367e-01       0.000000    0.000000
# 50%       3.000000  117.000000   1.496408e-01      23.000000   30.500000
# 75%       6.000000  140.250000   5.632228e-01      32.000000  127.250000
# max      17.000000  199.000000   2.734528e+00      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#yesari purei column ma nai scaling grnaa sakenchha
#

# %%
df = pd.read_csv('Diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
minmax = MinMaxScaler()
df['BloodPressure'] = minmax.fit_transform(df[['BloodPressure']])

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148       0.590164             35        0  33.6
# 1            1       85       0.540984             29        0  26.6
# 2            8      183       0.524590              0        0  23.3
# 3            1       89       0.540984             23       94  28.1
# 4            0      137       0.327869             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
yehaa feri blood pressure ko value change vayo.

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531       0.566438      20.536458   79.799479
# std       3.369578   31.972618       0.158654      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000       0.508197       0.000000    0.000000
# 50%       3.000000  117.000000       0.590164      23.000000   30.500000
# 75%       6.000000  140.250000       0.655738      32.000000  127.250000
# max      17.000000  199.000000       1.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
blood pressure ko describe gareara herdaa min => 0 , max => 1 aaunu parchhaa

# %%
again yehi dataa read garnee but range different diyeraa hernee

# %%
df = pd.read_csv('Diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
minmax = MinMaxScaler(feature_range=(2,5))
#feature_range deyeraa chaai parameter pass garne ie; different range dene
df['BloodPressure'] = minmax.fit_transform(df[['BloodPressure']])

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531       3.699315      20.536458   79.799479
# std       3.369578   31.972618       0.475962      15.952218  115.244002
# min       0.000000    0.000000       2.000000       0.000000    0.000000
# 25%       1.000000   99.000000       3.524590       0.000000    0.000000
# 50%       3.000000  117.000000       3.770492      23.000000   30.500000
# 75%       6.000000  140.250000       3.967213      32.000000  127.250000
# max      17.000000  199.000000       5.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
now yehaa bloodpressure min 2 dhekhi max 5 sammaa dekenchha
ie: range change vayo

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148       3.770492             35        0  33.6
# 1            1       85       3.622951             29        0  26.6
# 2            8      183       3.573770              0        0  23.3
# 3            1       89       3.622951             23       94  28.1
# 4            0      137       2.983607             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
help(MinMaxScaler)
# Out:
# Help on class MinMaxScaler in module sklearn.preprocessing._data:
#
# class MinMaxScaler(sklearn.base.OneToOneFeatureMixin, sklearn.base.TransformerMixin, sklearn.base.BaseEstimator)
#  |  MinMaxScaler(feature_range=(0, 1), *, copy=True, clip=False)
#  |
#  |  Transform features by scaling each feature to a given range.
#  |
#  |  This estimator scales and translates each feature individually such
#  |  that it is in the given range on the training set, e.g. between
#  |  zero and one.
#  |
#  |  The transformation is given by::
#  |
#  |      X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#  |      X_scaled = X_std * (max - min) + min
#  |
#  |  where min, max = feature_range.
#  |
#  |  This transformation is often used as an alternative to zero mean,
#  |  unit variance scaling.
#  |
#  |  `MinMaxScaler` doesn't reduce the effect of outliers, but it linearly
#  |  scales them down into a fixed range, where the largest occurring data point
# ...

# %%
#minmax kun belaa kun bealaa standard scaling use garne?
-> dherei jaso standard scaling use garenchha.
->

# %% [markdown]
# ### Note: Scaling is done after train_test split

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
or # from sklearn.preprocessing import MinMaxScaler , StandardScaler 
yesto garnaa sakenchhaa

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('Diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = data[['Glucose','Age']]
y = data.Outcome

# %%
x
# Out:
#      Glucose  Age
# 0        148   50
# 1         85   31
# 2        183   32
# 3         89   21
# 4        137   33
# ..       ...  ...
# 763      101   63
# 764      122   27
# 765      121   30
# 766      126   47
# 767       93   23
#
# [768 rows x 2 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2, random_state =9)

# %%
xtrain.head()
# Out:
#      Glucose  Age
# 476      105   29
# 448      104   22
# 518       76   41
# 221      158   66
# 453      119   72

# %%
Gulcose : standardScaler: x - mean/std
Age: StandardScaler : x - mean/std

# %%
target lai scaling garnu pardennaa. independent variable(predictor) lai matraa ho scaling garnu parnee

# %%
xtrain_s = scaler.fit_transform(xtrain) 

xtest_s = scaler.transform(xtest) #xtest ma fit gardenaa kinaki xtrain le store gareraa rakhechhaa fit lai

# %%
xtrain_s
# Out:
# array([[-0.51338073, -0.36368189],
#        [-0.54513091, -0.95264373],
#        [-1.4341359 ,  0.645967  ],
#        ...,
#        [-0.76738216, -0.11126967],
#        [-0.7038818 , -0.61609411],
#        [-0.38638002, -1.03678114]], shape=(614, 2))

# %% [raw]
# fit ma 2 opearation chha that is
# .fit()           -> fit le mean ra std calucalte gareraa rakhcaa
# .transform()     -> tyo mean ra std lagayeraa opearation garchhaa

# %%
first ma train test split then balla data scaling garenchha

# %%
scaler = StandardScaler()
xnew = scaler.fit_transfrom(x)

# %%
fit ma 2 opearation chha that is 
.fit()           -> fit le mean ra std calucalte gareraa rakhcaa
.transform()     -> tyo mean ra std lagayeraa opearation garchhaa

# %%
train-split ma k vanchhaa vandaa mean ra standard deviation nekaldaa tyo mean ra standard
deviation chia training data bata matraa leney vanchhha.
