# %%
 python framework => streamlit : ML model
kunei model ley fit garnaaa chhaa  bhaney tyo file lai open gareraa aagadi bataa run gardei aaunu parchhaa.
BUT
tyo model lai download gareraa rakhenchha ani yekei patak ma fit garechhaa .

# %%
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('Diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = data[['Glucose','BloodPressure', 'DiabetesPedigreeFunction','Age']]

# %%
x
# Out:
#      Glucose  BloodPressure  DiabetesPedigreeFunction  Age
# 0        148             72                     0.627   50
# 1         85             66                     0.351   31
# 2        183             64                     0.672   32
# 3         89             66                     0.167   21
# 4        137             40                     2.288   33
# ..       ...            ...                       ...  ...
# 763      101             76                     0.171   63
# 764      122             70                     0.340   27
# 765      121             72                     0.245   30
# 766      126             60                     0.349   47
# 767       93             70                     0.315   23
#
# [768 rows x 4 columns]

# %%
y = data.Outcome

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
xtrain, xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2 , random_state= 90)

# %%
dmodel = DecisionTreeClassifier(max_depth = 7)
dmodel.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
#model evaluation
yprediction = dmodel.predict(xtest)

# %%
accuracy = accuracy_score(ytest,yprediction)
print(f'Accuracy = {accuracy:.2%}')
# Out:
# Accuracy = 70.13%

# %%
#Glucose = 200
# Blood pressure = 140
#DFP = 0.9
#Age = 40

dmodel.predict([[200,140,0.9,40]])
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
import joblib #model lai save garnaa ko lagi
 #joblib.dump()

 #joblib.load()
#or import pickle  gardaaa ni hunchhaa.

# %%
joblib.dump(dmodel,'DecisionTreePrediction.pkl')
# Out:
# ['DecisionTreePrediction.pkl']

# %%
#Load Model
model_d = joblib.load('DecisionTreePrediction.pkl')

# %%
model_d
# Out:
# DecisionTreeClassifier(max_depth=7)

# %%
model_d.predict([[200,140,0.9,40]])
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
#Random forest classifier. 
-it comes under ensemble learning
-- ensemble learning ko pani bagging mam parchha. 
ensemble learning -combines the result of multiple learner 
--dhrei otaaa expert lai sodnneee. 
-- builds multiple decision trees.

# %%
Glucose , BLoodPressure , DFP , Age 

sab data sab vayesi ta jati otaa decision tree pani yeutei bandenaa ta?

# %%
=> Random Forest
      Decision Tree1
            200 rows (training)
           random  sampling garchhaa aagdi ko decision tree ma ..

# %%
import pandas as pd

# %%
data = pd.read_csv('Diabetes.csv')
data.head(10)   #training mai 10 otaaa otaaa chhaa
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
x = data[['Glucose','BloodPressure', 'DiabetesPedigreeFunction','Age']]

# %%
Decision tree ko first sampling ma , jasta ko tastei 10 ottaa row ledenaa.
bhannu ko meaning yeutei 2 patak repaet hunaa ni payo j garnaa ni payo randomly 10 ottaaa pick garchhaa
, kunei rows multiple time sleect hunaa ni sakchhaa, kunei select nai nahuna pani saskchhaaa. 



ie: Randomsampling -- select 10 rows

# %%
Decision 2 ma pani same testei hunchhaaa , farak farak data linaa sakchhaaa 10 patak...

# %%
Boot Strap Samples --> total maddhe yeutaaa lai randomly select garneee ani oick garneee, pick vaisakkeo mannchee pani feri basney line ma

eg: 6 otaa choclate badhha, sir ley first ma malai sekect garnu vayo , aarko patak feri ma bahira gayeraa basne hainaa tehi basneyy, arko hhoti badhhaa 
ma parnaa ki sakchhu na parnaa ni sakchhuu.

# %%
2 otaaa technique hunchhaan random forest ko pani
1) random sampling
2) randomly feature selection 


jun badi pick vayo randomly , teslai last ma leney(jun badi pick vayo tehi leney)

# %%
feature bhaneko column
-> rows lai chhai repeat garnnaa sakchhaa but feature lai chai gardena

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
y = data.Outcome

# %%
xtrain , xtest, ytrain,ytest = train_test_split(x,y,test_size = 0.2 , random_state = 5)

# %%
rf_model = RandomForestClassifier(n_estimators = 200)
rf_model.fit(xtrain , ytrain)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rf_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 200,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
yprediction = rf_model.predict(xtest)

# %%
accuracy = accuracy_score(ytest,yprediction)
print(accuracy)
# Out:
# 0.7467532467532467

# %%
time complexity high hunchhaaa random forest ko
kinaki dherei decision tree banaudei chham , so ofc time ta lagchha...

# %% [markdown]
# ![image.png](attachment:648b69a9-4031-4d64-ae94-abc8b0779f8e.png)
