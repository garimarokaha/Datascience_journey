# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')

# %%
print(data)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#2) seee the first 15 entries
result =data.head(15)
print(result)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
#3) see the last 10 entities
data.tail(10)
# Out:
#      PassengerId  Pclass                                             Name  \
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 408  female   NaN      0      0              334915    7.7208   NaN        Q
# ...

# %%
# 4) what is the shape of the dataset
data.shape
# Out:
# (418, 11)

# %%
 #shape=> #this means it has 418 rows and 11 columns

# %%
# Qn5) what is the number of observation in the datasets?
# observation in the dataset means the number of rows in the dataset.
# shape is used for no of rows and columns 
# shape[0]=> rows
# shape[1]=>columns


print("Number of observations:", data.shape[0])
# Out:
# Number of observations: 418

# %%
#Qn6) what is the number of columns in the dataset?
# for column shape[1]

print("Number of columns:", data.shape[1])
# Out:
# Number of columns: 11

# %%
#Qn7) Print the name of all the columns 
print("Name of columns are:", data.columns)
# Out:
# Name of columns are: Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Qn8) Print only the Pclass column
data.Pclass
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
#or

# %%
data['Pclass']
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      3
#       ..
# 413    3
# 414    1
# 415    3
# 416    3
# 417    3
# Name: Pclass, Length: 418, dtype: int64

# %%
#Qn9) What are the differenet values in Pclass column
# different values in pclass column means unique values
data.Pclass.unique()
# Out:
# array([3, 2, 1])

# %%
#or
data['Pclass'].unique()
# Out:
# array([3, 2, 1])

# %%
#Qn10) How many different Pclass are in the dataset.
 # nunique()=> count the number of unique value in the dataset.
data['Pclass'].nunique()
# Out:
# 3

# %%
#Qn11) Summarize the dataset.(using describe() function)
print("summarize of the dataset:", data.describe())
# Out:
# summarize of the dataset:        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
#Qn12) Summarize only the age column 
age_summary = data['Age'].describe()
print(age_summary)
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
# Qn13) what is the mean age of the passengers.
mean_age_of_passengers = data['Age'].mean()
print(mean_age_of_passengers)
# Out:
# 30.272590361445783

# %%
#extra questions

# %%
Some other functions of dataframe 
1)df.isnull()=> detects the missing values (NaN)
NaN => Not a number

# %%
data.isnull()
# Out:
#      PassengerId  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0          False   False  False  False  False  False  False   False  False
# 1          False   False  False  False  False  False  False   False  False
# 2          False   False  False  False  False  False  False   False  False
# 3          False   False  False  False  False  False  False   False  False
# 4          False   False  False  False  False  False  False   False  False
# ..           ...     ...    ...    ...    ...    ...    ...     ...    ...
# 413        False   False  False  False   True  False  False   False  False
# 414        False   False  False  False  False  False  False   False  False
# 415        False   False  False  False  False  False  False   False  False
# 416        False   False  False  False   True  False  False   False  False
# 417        False   False  False  False   True  False  False   False  False
#
#      Cabin  Embarked
# 0     True     False
# 1     True     False
# ...

# %%
#dropna()=> remove rows with missing values
data.dropna()
# Out:
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 28           920       1                            Brady, Mr. John Bertram
# ..           ...     ...                                                ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 405         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
#df.fillna(value)=> fills the missing value with a specified value
data.fillna(1)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
