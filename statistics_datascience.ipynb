# %%
#Population and sampling
->population :: thulo set of dataa that are the subject of a statistical study.
                complete set of dataset

-->sample    :: population kei subset.

# %%
Descriptive statistics :
 --yesle data lai explain gardenchhaaa

Inferencial statistics:
--decision lene or kehi derive gardeney

# %%
Types of data:
nominal scale, interval scale, ordinal scale ,

# %%
Centrality Measures

-> Central Tendency:
  - full dataset ko yeutaa representative ho central tendency bhaneko.
  - central bhaneko bich ma ra tendency bhaneko lie garneee nature
     ie: major dataa central ma parnee tendency hunchaa so central tendendency.

1) Mean::->  missing data fill garna mean use garnaa sakenchha. 
         -> not suggested for qualitative data(yedi tyo column numeric chha bhaney mean use garnaa sakenchhaa but categorical(qualitative ) data bhako vaye mean 
         suggested garedainnaa)
         -> outliers huda mean prefer garedainaa.
        -> not suggested for open _ended class.

2) Median ::middle most or central dataa.
]         -> etreme value le affect gardeinaa.
          


3) Mode:: highest frequency
         -> jun badi occur vako chhaa ie: mode

# %%
data ko distribution  banauna  paryo bhane histogran use hunchha.

# %%
Symmetrical curve: 
Bell shape ko curve banchhaa .
aagadi 50%, pachhadi 50% gareraa equal shape ma distribute hunchhaa.

# %%
jaha tiraa peak hunchhaa tyo mode ho.
mean lai etrame vakue key affect garchhaa.

# %%
Dispersion: data scatter katti ko vako chhaa? 
-> central tendency matraa enough hudenaa kinaki kunei dataa ko distribuition farak vayeni mean same aauna sakchhaa.
so we use dispersion
1> range: largest-smallest (kaha bata kaha sammaa)
2> Interquartile Range : Q3-Q1
3> Standard deviation  
4> Variance: average ma mean bhanda point haru kati ley vary hunchhaa.
           : SD ko square root 
            :

# %%
variance and standard deviation.
