# %%
#Overfitting lai control garnee

# %%
#Overfitting
#Underfitting

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.tree import DecisionTreeClassifier ,plot_tree
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

# %%
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x = data.drop('species',axis =1)
y = data.species

# %%
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2, random_state =7)

# %%
dmodel = DecisionTreeClassifier()
dmodel.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
#testing ko accurcy nekalne

# %%
yprediction = dmodel.predict(xtest)
accuracy = accuracy_score(ytest,yprediction)

print(f'Accuracy:{accuracy:.2%}')
# Out:
# Accuracy:90.00%

# %%
#training accuracy
ypred_train = dmodel.predict(xtrain)
accuracy_train = accuracy_score(ytrain,ypred_train)

print(f'Accuracy:{accuracy_train:.2%}')
# Out:
# Accuracy:100.00%

# %%
train ma sabeidata meleko chhaa so acuracy 100%, yo pani suspecious ho so overfitting.

# %%
features = list(x.columns)
clas = list(y.unique())

# %%
plot_tree(dmodel,feature_names=features,class_names=clas,filled = True)
plt.show()

# %%
depth -> aafu bhanda kati muni sammmaa gako chhaa, harek node ko chhutataa chhuteii hunchhaa
tree ko depth ra label equal hunchhca.
depth hernaa lai aafu bhanda mathi hernee , kati chha bhanera

# %%
df = pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
x = df[['Glucose','Age']]
y = df.Outcome

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size = 0.2, random_state =7)

# %%
dmodel = DecisionTreeClassifier()
dmodel.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
#test accuracy
yprediction = dmodel.predict(xtest)
accuracy = accuracy_score(ytest,yprediction)

print(f'Accuracy:{accuracy:.2%}')
# Out:
# Accuracy:68.18%

# %%
#training accuracy
ypred_train = dmodel.predict(xtrain)
accuracy_train = accuracy_score(ytrain,ypred_train)

print(f'Accuracy:{accuracy_train:.2%}')
# Out:
# Accuracy:97.56%

# %%
#decison tree

# %%
plot_tree(dmodelfilled = True)
plt.show()

# %%
dmodel2 = DecisionTreeClassifier(max_depth = 6)
dmodel2.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=6)

# %%
plot_tree(dmodel2,filled= True)
plt.show()

# %%
#test accuracy
yprediction = dmodel2.predict(xtest)
accuracy = accuracy_score(ytest,yprediction)

print(f'Accuracy:{accuracy:.2%}')
# Out:
# Accuracy:75.97%

# %%
#train accuracy
yprediction = dmodel2.predict(xtrain)
accuracy = accuracy_score(ytrain,yprediction)

print(f'Accuracy:{accuracy:.2%}')
# Out:
# Accuracy:79.97%

# %%
help( DecisionTreeClassifier()
# Out:
# Help on DecisionTreeClassifier in module sklearn.tree._classes object:
#
# class DecisionTreeClassifier(sklearn.base.ClassifierMixin, BaseDecisionTree)
#  |  DecisionTreeClassifier(
#  |      *,
#  |      criterion='gini',
#  |      splitter='best',
#  |      max_depth=None,
#  |      min_samples_split=2,
#  |      min_samples_leaf=1,
#  |      min_weight_fraction_leaf=0.0,
#  |      max_features=None,
#  |      random_state=None,
#  |      max_leaf_nodes=None,
#  |      min_impurity_decrease=0.0,
#  |      class_weight=None,
#  |      ccp_alpha=0.0,
#  |      monotonic_cst=None
#  |  )
#  |
#  |  A decision tree classifier.
#  |
#  |  Read more in the :ref:`User Guide <tree>`.
#  |
#  |  Parameters
#  |  ----------
#  |  criterion : {"gini", "entropy", "log_loss"}, default="gini"
#  |      The function to measure the quality of a split. Supported criteria are
#  |      "gini" for the Gini impurity and "log_loss" and "entropy" both for the
# ...

# %%
yo tree big banyo, yo bhannaa denu hdueunaa yeslai rokne technique haru pani chhan 
1> depth 
   depth = fix value
  deyeko depth sammmaa ko bannaa payo tehaa bhanda badi nabanaune

2>

# %%
#Grid Search -> kun depth ma accuracy high aauchhaa bahneraa check gareko? 
             -> balanced depth denu parchhaa.
            -> depth thorei vaye underfitting
            -> depth dhrei vaye overfitting

-> hamley deko parameters sabei ma run gardenchhaa ra best chai ledenchha

# %%
from sklearn.model_selection import GridSearchCV

# %%
dmodel3 = DecisionTreeClassifier()

# %%
parameters = {
    'max_depth':[4,5,6,7]  #yehaa max depth nai lagaina aparchhaa because it is a parameter of decisontreeclassifier
}

# %%
grid_search = GridSearchCV(
    estimator = DecisionTreeClassifier() ,
    param_grid = parameters,
    scoring = 'accuracy',
    cv = 5
)
grid_search.fit(xtrain , ytrain)

#estimators bhaneko decision tree calssifier nai ho
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [4, 5, 6, 7]}, scoring='accuracy')

# %%
help(GridSearchCV)

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
grid_search.best_score_    
#cv =5 lagako chha hamley, yesle yeutaa max depth 4 lida 4 patak fir garchhaa, harek patak fit harek different accuarcy aayo tyo
#sabko average bhaenko maxaccuracy

#cv = 5
#max_depth = 4:
#acc       acc1       acc2      acc3      acc4       acc
#max_depth = 5
# Out:
# np.float64(0.7247500999600159)

# %%
dmodel = DecisionTreeClassifier(max_depth =5)
dmodel.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
#parameeter herna lai decision tree ko

dmodel.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
max_depth :            :
max_features :         :
max_leaf_nodes:none   :max kati leaf, jati dherei leaf teti dherei path , we need 3 0r 4 max leaf
min_simple_leaf:1      : leaf ma minimum sample default ma 1 chhaa, hamley set garnana saskenchhaa eg: 10  bhaneko , leaf bannaa 10 otaa sample hunei parchha
                        yeutaa yeutaa path bhaenko haru cut bhaidenchhaaa yesto gardaa

min_sample_split :2    :split hudei chhaa bahney minumum kati otaa sample bayesi matraa split huney taa. default 2 chhaaa bhaneko 
                        2 otaa vayesi yeuata yeutaa ma split bvaidenchhca
                   eg : node split hudei chha bhaney miminum pani 15 otaaa sample chaiyoo.

# %%
parametes = {
    'max_depth':[4,5,6,7],
    'min_samples_leaf':[10 ,15]    # 4 hudaa 10,15   , 5 huda   10,15   , 6 ra 7 huda ni 10,15 so 8 otaaa total
}

# %%
yo parameters haru use gareraaa overfitting lai control garnnaa sakenchhaa
